# %%
# Génère un nouveau jeton d'accès pour utiliser les API d'Algoan
import requests
url = "https://api.algoan.com/v1/oauth/token"
headers = {}
payload = {"client_id": "82dde8fc8e98f2880ee4256b","client_secret":"IV2Ie8SOIAb0iAIEnHMd2HI6uF4BhlT2","grant_type":"client_credentials"}

response = requests.request("POST", url, headers=headers, data=payload)


print(response.json())
access_token = response.json()["access_token"]

access_token

headers = {
    "Authorization":"Bearer " + access_token}
# Out:
# {'access_token': 'eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJScFd1TnVyX1ZESW1meUxGeXh3MUxTWnZsMzdVQURtUkhHZUlyZkVZQlp3In0.....MfqYFhbeNKzcRmmaS0cUSoACJMG5qCFGuNwOfAN7jB0lRQSXr4jT6H2vactdoSECMoalx1oWb8iyCxndCRISsPzIwo0cwr9BPbgyktzPYwqzYP4Z9UTBHEMX7zOvdLqxtwhpt_xTrYv93VxvES5i_yALLWR_bPDTwopAfIUPoh2EfQjZc2XkCzqOVXMlwLgnKF4m8qL9BtdRHrHT-pmWN6U4eOzkc1szsWM4TiTQFa04P5NU4zF9-DgczN6sOBtY8R3Sm5AtC-cUy2-Owt-yN0R4JApSlnDChEq_KUgBGGQ0Sxvb-k4hB-dYv-RThSAgkTXSbfZduEeWrhCYr4HCcw', 'expires_in': 299, 'refresh_expires_in': 2591999, 'refresh_token': 'eyJhbGciOiJIUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJjMDBlMzg1OC1mZGQ3LTRhNTEtYWRhNy1kZGNmOGFjYTkzMjUifQ.....jctePQwWXrf67Y9m6wn5MPppaqfUgQsSUz39gf2P8q4', 'token_type': 'Bearer', 'not-before-policy': 1566572780, 'session_state': 'c2c7033d-9bd7-47ed-94ef-c0cdc364d9e9', 'scope': 'profile email'}

# %%
url = "https://api.algoan.com/v2/customers"
headers = {
    "Authorization":"Bearer " + access_token}
querystring = {"limit":100,"page":1,"filter":None}

response = requests.request("GET", url, headers=headers,params=querystring)

response.json()
# Out:
# {'resources': [{'customIdentifier': '1234',
#    'aggregationDetails': {},
#    'reports': {'completedAnalyses': {'count': 0}},
#    'shares': [],
#    'storage': {'type': 'PARTIAL_DELETION',
#     'expiresAt': '2023-01-05T12:31:04.606Z'},
#    'createdAt': '2022-10-07T12:31:04.608Z',
#    'updatedAt': '2022-10-07T12:31:04.608Z',
#    'id': '63401c08c8eee7268ddeb22d'},
#   {'customIdentifier': '12345',
#    'aggregationDetails': {},
#    'reports': {'completedAnalyses': {'count': 0}},
#    'shares': [],
#    'storage': {'type': 'PARTIAL_DELETION',
#     'expiresAt': '2023-01-05T12:38:25.371Z'},
#    'createdAt': '2022-10-07T12:38:25.382Z',
#    'updatedAt': '2022-10-07T12:38:25.382Z',
#    'id': '63401dc172bd66d93ba1f7d8'},
#   {'customIdentifier': '123456',
#    'aggregationDetails': {'userId': 'string',
#     'callbackUrl': 'REDIRECT',
# ...

# %%
list_client= response.json()["resources"]
list_client
# Out:
# [{'customIdentifier': '1234',
#   'aggregationDetails': {},
#   'reports': {'completedAnalyses': {'count': 0}},
#   'shares': [],
#   'storage': {'type': 'PARTIAL_DELETION',
#    'expiresAt': '2023-01-05T12:31:04.606Z'},
#   'createdAt': '2022-10-07T12:31:04.608Z',
#   'updatedAt': '2022-10-07T12:31:04.608Z',
#   'id': '63401c08c8eee7268ddeb22d'},
#  {'customIdentifier': '12345',
#   'aggregationDetails': {},
#   'reports': {'completedAnalyses': {'count': 0}},
#   'shares': [],
#   'storage': {'type': 'PARTIAL_DELETION',
#    'expiresAt': '2023-01-05T12:38:25.371Z'},
#   'createdAt': '2022-10-07T12:38:25.382Z',
#   'updatedAt': '2022-10-07T12:38:25.382Z',
#   'id': '63401dc172bd66d93ba1f7d8'},
#  {'customIdentifier': '123456',
#   'aggregationDetails': {'userId': 'string',
#    'callbackUrl': 'REDIRECT',
# ...

# %%
url = "https://api.algoan.com/v2/customers"

payload = {
  "customIdentifier": "1234567",
  "aggregationDetails": {
    "callbackUrl": "REDIRECT",
    "token":"",
    "redirectUrl":"string",
    "apiUrl": "string",
    "iframeUrl": "string",
    "userId": "string",
    "clientId": "string"
  },
  "personalDetails": {
    "firstName": "zhang leon",
    "contact": {
      "email": "zhangleon1985@gmail.com",
      "phoneNumber": "+33767852794",
      "street": "151 rue saint denis",
      "additionalInformation": "second Floor",
      "city": "ROUAIX",
      "zipCode": "59100",
      "country": "FR"
    },
    "household": {
      "maritalStatus": "CIVIL_PARTNERSHIP",
      "numberOfDependentChildren": 2,
      "numberOfOtherDependents": 0
    }
  }
}

response = requests.request("POST", url, headers=headers, json=payload)

print(response.text)
response
# Out:
# {"code":"ALREADY_EXISTS","message":"customIdentifier 1234567 already exists","status":422}

# %%
import requests

customer_id = 1234567

url = f"https://api.algoan.com/v2/customer/{customer_id}/analyses"

payload = {}
headers = {
    "Content-Type": "json",
    "Authorization": "Bearer access_token"
}

response = requests.request("post", url, json=payload, headers=headers)

print(response.text)
# Out:
# <html>
# <head><title>404 Not Found</title></head>
# <body>
# <center><h1>404 Not Found</h1></center>
# <hr><center>nginx</center>
# </body>
# </html>

# %%
payload = {
    "format": "BUDGET_INSIGHT_V2_0",
    "connections": [
      {
        "accounts": [
          {
            "transactions": [
              {
                "date": "2022-07-11T05:00:00.000Z",
                "rdate": "2022-07-11T05:00:00.000Z",
                "currency": "EUR",
                "value": -101.67,
                "original_wording": "PRELEVEMENT HARRY POTTER PRELEVEMENT CARTE ZERO FAST3280420323",
                "id": 471
              },
              {
                "date": "2022-07-11T05:00:00.000Z",
                "rdate": "2022-07-11T05:00:00.000Z",
                "currency": "EUR",
                "value": -150,
                "original_wording": "PRLV SEPA POTTER HARRY ECH ID EMETTEUR/LU66ZZZ000023 MDT/3BEAC43A69zeeeeAC6 REF/1B0F18BC115A4788DA4 LIB/PRELEVEMENT CARTE ZERO FSSI043def106",
                "id": 290
              },
              {
                "date": "2022-07-12T05:00:00.000Z",
                "rdate": "2022-07-12T05:00:00.000Z",
                "currency": "EUR",
                "value": -75.2,
                "original_wording": "PRELEVEMENT DE NAVIGO ANNUEL - G COMUTITRES REF : 3/262663-1/92921 Navigo Annuel",
                "id": 347
              },
              {
                "date": "2022-07-12T05:00:00.000Z",
                "rdate": "2022-07-12T05:00:00.000Z",
                "currency": "EUR",
                "value": -399.89,
                "original_wording": "PRLV SEPA CREDIPAR Motif : 101M3323222 32 VOTRE IDEN",
                "id": 633
              },
              {
                "date": "2022-07-12T05:00:00.000Z",
                "rdate": "2022-07-12T05:00:00.000Z",
                "currency": "EUR",
                "value": -879.78,
                "original_wording": "VIREMENT EMIS AG HOMALONE LOYER",
                "id": 124
              },
              {
                "date": "2022-07-14T05:00:00.000Z",
                "rdate": "2022-07-14T05:00:00.000Z",
                "currency": "EUR",
                "value": -77.99,
                "original_wording": "PAIEMENT CB PARIS CARREFOUR PARIS CARTE 122131",
                "id": 593
              },
              {
                "date": "2022-07-14T05:00:00.000Z",
                "rdate": "2022-07-14T05:00:00.000Z",
                "currency": "EUR",
                "value": -67.2,
                "original_wording": "PRELEVEMENT DE ADVANZIA BANK S.A REF : efefefefef 3c6 PRELEVEMENT CARTE ZERO FUBL",
                "id": 590
              },
              {
                "date": "2022-07-14T05:00:00.000Z",
                "rdate": "2022-07-14T05:00:00.000Z",
                "currency": "EUR",
                "value": 900,
                "original_wording": "VIREMENT RECU DE M. POTTER",
                "id": 981
              },
              {
                "date": "2022-07-15T05:00:00.000Z",
                "rdate": "2022-07-15T05:00:00.000Z",
                "currency": "EUR",
                "value": -4.99,
                "original_wording": "Cotisation Compte A Composer (rem = 20%)",
                "id": 287
              },
              {
                "date": "2022-07-15T05:00:00.000Z",
                "rdate": "2022-07-15T05:00:00.000Z",
                "currency": "EUR",
                "value": -343.45,
                "original_wording": "PRLV SEPA CREDIPAR 10600220302032 32 VOTRE IDE FR0004123032023",
                "id": 678
              },
              {
                "date": "2022-07-19T05:00:00.000Z",
                "rdate": "2022-07-19T05:00:00.000Z",
                "currency": "EUR",
                "value": -126.99,
                "original_wording": "CARTE X2518 3-4X CB ONEY. COMMERCE ELECTRONIQUE",
                "id": 415
              },
              {
                "date": "2022-07-19T05:00:00.000Z",
                "rdate": "2022-07-19T05:00:00.000Z",
                "currency": "EUR",
                "value": -20,
                "original_wording": "PRELEVEMENT DE LUKO COVER SAS REF : 2RQ0IPC LUKO COVER SAS",
                "id": 121
              },
              {
                "date": "2022-07-26T05:00:00.000Z",
                "rdate": "2022-07-26T05:00:00.000Z",
                "currency": "EUR",
                "value": -5.49,
                "original_wording": "CARTE X2518 APPLE.COM/BILL 5,49 EUR IRLANDE COMMERCE ELECTRONIQUE",
                "id": 233
              },
              {
                "date": "2022-07-29T05:00:00.000Z",
                "rdate": "2022-07-29T05:00:00.000Z",
                "currency": "EUR",
                "value": -9.99,
                "original_wording": "CARTE X2518 SPOTIFY FRANCE COMMERCE ELECTRONIQUE",
                "id": 964
              },
              {
                "date": "2022-07-29T05:00:00.000Z",
                "rdate": "2022-07-29T05:00:00.000Z",
                "currency": "EUR",
                "value": -15.99,
                "original_wording": "PRELEVEMENT DE BOUYGUES TELECOM YGUES TELECOM REF : PAGP0102EAAE 06xxxxx685",
                "id": 897
              },
              {
                "date": "2022-08-05T05:00:00.000Z",
                "rdate": "2022-08-05T05:00:00.000Z",
                "currency": "EUR",
                "value": -227.89,
                "original_wording": "PAIEMENT CB PARIS CARREFOUR PARIS CARTE 122131",
                "id": 706
              },
              {
                "date": "2022-08-05T05:00:00.000Z",
                "rdate": "2022-08-05T05:00:00.000Z",
                "currency": "EUR",
                "value": 2581.45,
                "original_wording": "VIR SEPA RECU /DE FNAC DARTY PARTICIPATIONS ET SERVICES /MOTIF SALAIRE /REF 106837-2",
                "id": 761
              },
              {
                "date": "2022-08-06T05:00:00.000Z",
                "rdate": "2022-08-06T05:00:00.000Z",
                "currency": "EUR",
                "value": 5500,
                "original_wording": "VIREMENT DE SOGEFINANCE 2914101O4 VERSEMENT PRET PERSONNEL 424144",
                "id": 237
              },
              {
                "date": "2022-08-07T05:00:00.000Z",
                "rdate": "2022-08-07T05:00:00.000Z",
                "currency": "EUR",
                "value": -5500,
                "original_wording": "VIREMENT COMPTE A COMPTE MME POTTER",
                "id": 31
              },
              {
                "date": "2022-08-08T05:00:00.000Z",
                "rdate": "2022-08-08T05:00:00.000Z",
                "currency": "EUR",
                "value": -112.32,
                "original_wording": "PRELEVEMENT DE EDF CLIENTS PARTI iers REF : Z012201022 00203 1 S 114",
                "id": 428
              },
              {
                "date": "2022-08-11T05:00:00.000Z",
                "rdate": "2022-08-11T05:00:00.000Z",
                "currency": "EUR",
                "value": -101.67,
                "original_wording": "PRELEVEMENT HARRY POTTER PRELEVEMENT CARTE ZERO FAST3280420323",
                "id": 173
              },
              {
                "date": "2022-08-11T05:00:00.000Z",
                "rdate": "2022-08-11T05:00:00.000Z",
                "currency": "EUR",
                "value": -356.99,
                "original_wording": "CARTE FNAC",
                "id": 659
              },
              {
                "date": "2022-08-11T05:00:00.000Z",
                "rdate": "2022-08-11T05:00:00.000Z",
                "currency": "EUR",
                "value": -399.89,
                "original_wording": "PRLV SEPA CREDIPAR Motif : 101M3323222 32 VOTRE IDEN",
                "id": 676
              },
              {
                "date": "2022-08-11T05:00:00.000Z",
                "rdate": "2022-08-11T05:00:00.000Z",
                "currency": "EUR",
                "value": -150,
                "original_wording": "PRLV SEPA POTTER HARRY ECH ID EMETTEUR/LU66ZZZ000023 MDT/3BEAC43A69zeeeeAC6 REF/1B0F18BC115A4788DA4 LIB/PRELEVEMENT CARTE ZERO FSSI043def106",
                "id": 481
              },
              {
                "date": "2022-08-12T05:00:00.000Z",
                "rdate": "2022-08-12T05:00:00.000Z",
                "currency": "EUR",
                "value": -900,
                "original_wording": "VIREMENT EMIS M POTTER",
                "id": 12
              },
              {
                "date": "2022-08-12T05:00:00.000Z",
                "rdate": "2022-08-12T05:00:00.000Z",
                "currency": "EUR",
                "value": -75.2,
                "original_wording": "PRELEVEMENT DE NAVIGO ANNUEL - G COMUTITRES REF : 3/262663-1/92921 Navigo Annuel",
                "id": 870
              },
              {
                "date": "2022-08-12T05:00:00.000Z",
                "rdate": "2022-08-12T05:00:00.000Z",
                "currency": "EUR",
                "value": -879.78,
                "original_wording": "VIREMENT EMIS AG HOMALONE LOYER",
                "id": 574
              },
              {
                "date": "2022-08-15T05:00:00.000Z",
                "rdate": "2022-08-15T05:00:00.000Z",
                "currency": "EUR",
                "value": -4.99,
                "original_wording": "Cotisation Compte A Composer (rem = 20%)",
                "id": 470
              },
              {
                "date": "2022-08-15T05:00:00.000Z",
                "rdate": "2022-08-15T05:00:00.000Z",
                "currency": "EUR",
                "value": -343.45,
                "original_wording": "PRLV SEPA CREDIPAR 10600220302032 32 VOTRE IDE FR0004123032023",
                "id": 566
              },
              {
                "date": "2022-08-15T05:00:00.000Z",
                "rdate": "2022-08-15T05:00:00.000Z",
                "currency": "EUR",
                "value": 343.45,
                "original_wording": "REJET PRLV SEPA CREDIPAR",
                "id": 99
              },
              {
                "date": "2022-08-16T05:00:00.000Z",
                "rdate": "2022-08-16T05:00:00.000Z",
                "currency": "EUR",
                "value": -29.12,
                "original_wording": "PRELEVEMENT DE ADVANZIA BANK S.A REF : efefefefef 3c6 PRELEVEMENT CARTE ZERO FUBL",
                "id": 512
              },
              {
                "date": "2022-08-19T05:00:00.000Z",
                "rdate": "2022-08-19T05:00:00.000Z",
                "currency": "EUR",
                "value": -126.99,
                "original_wording": "CARTE X2518 3-4X CB ONEY. COMMERCE ELECTRONIQUE",
                "id": 543
              },
              {
                "date": "2022-08-19T05:00:00.000Z",
                "rdate": "2022-08-19T05:00:00.000Z",
                "currency": "EUR",
                "value": -20,
                "original_wording": "PRELEVEMENT DE LUKO COVER SAS REF : 2RQ0IPC LUKO COVER SAS",
                "id": 437
              },
              {
                "date": "2022-08-21T05:00:00.000Z",
                "rdate": "2022-08-21T05:00:00.000Z",
                "currency": "EUR",
                "value": -57.99,
                "original_wording": "PAIEMENT CB PARIS CARREFOUR PARIS CARTE 122131",
                "id": 130
              },
              {
                "date": "2022-08-29T05:00:00.000Z",
                "rdate": "2022-08-29T05:00:00.000Z",
                "currency": "EUR",
                "value": -9.99,
                "original_wording": "CARTE X2518 SPOTIFY FRANCE COMMERCE ELECTRONIQUE",
                "id": 398
              },
              {
                "date": "2022-08-29T05:00:00.000Z",
                "rdate": "2022-08-29T05:00:00.000Z",
                "currency": "EUR",
                "value": 9.99,
                "original_wording": "REJET PRLV SPOTIFY",
                "id": 251
              },
              {
                "date": "2022-08-30T05:00:00.000Z",
                "rdate": "2022-08-30T05:00:00.000Z",
                "currency": "EUR",
                "value": -15.99,
                "original_wording": "PRELEVEMENT DE BOUYGUES TELECOM YGUES TELECOM REF : PAGP0102EAAE 06xxxxx686",
                "id": 668
              },
              {
                "date": "2022-09-02T05:00:00.000Z",
                "rdate": "2022-09-02T05:00:00.000Z",
                "currency": "EUR",
                "value": -270.89,
                "original_wording": "PAIEMENT CB PARIS CARREFOUR PARIS CARTE 122131",
                "id": 250
              },
              {
                "date": "2022-09-06T05:00:00.000Z",
                "rdate": "2022-09-06T05:00:00.000Z",
                "currency": "EUR",
                "value": 2581.45,
                "original_wording": "VIR SEPA RECU /DE FNAC DARTY PARTICIPATIONS ET SERVICES /MOTIF SALAIRE /REF 106837-3",
                "id": 1
              },
              {
                "date": "2022-09-07T05:00:00.000Z",
                "rdate": "2022-09-07T05:00:00.000Z",
                "currency": "EUR",
                "value": -320,
                "original_wording": "VIREMENT ALICE AIRBNB",
                "id": 168
              },
              {
                "date": "2022-09-08T05:00:00.000Z",
                "rdate": "2022-09-08T05:00:00.000Z",
                "currency": "EUR",
                "value": -112.32,
                "original_wording": "PRELEVEMENT DE EDF CLIENTS PARTI iers REF : Z012201022 00203 1 S 115",
                "id": 154
              },
              {
                "date": "2022-09-08T05:00:00.000Z",
                "rdate": "2022-09-08T05:00:00.000Z",
                "currency": "EUR",
                "value": -343.45,
                "original_wording": "PRLV SEPA CREDIPAR 10600220302032 32 VOTRE IDE FR0004123032023 REPRESENTATION",
                "id": 939
              },
              {
                "date": "2022-09-10T05:00:00.000Z",
                "rdate": "2022-09-10T05:00:00.000Z",
                "currency": "EUR",
                "value": -34.89,
                "original_wording": "PRELEVEMENT DE ADVANZIA BANK S.A REF : efefefefef 3c6 PRELEVEMENT CARTE ZERO FUBL",
                "id": 166
              },
              {
                "date": "2022-09-11T05:00:00.000Z",
                "rdate": "2022-09-11T05:00:00.000Z",
                "currency": "EUR",
                "value": -123.02,
                "original_wording": "PRELEVEMENT EUROPEEN 0907476161 DE: PRET SOGEFINANC.EXPRESSO-SOGEFINANC EMENT ID: FR94ZZZ412211",
                "id": 892
              },
              {
                "date": "2022-09-11T05:00:00.000Z",
                "rdate": "2022-09-11T05:00:00.000Z",
                "currency": "EUR",
                "value": -101.67,
                "original_wording": "PRELEVEMENT HARRY POTTER PRELEVEMENT CARTE ZERO FAST3280420323",
                "id": 579
              },
              {
                "date": "2022-09-11T05:00:00.000Z",
                "rdate": "2022-09-11T05:00:00.000Z",
                "currency": "EUR",
                "value": -150,
                "original_wording": "PRLV SEPA POTTER HARRY ECH ID EMETTEUR/LU66ZZZ000023 MDT/3BEAC43A69zeeeeAC6 REF/1B0F18BC115A4788DA4 LIB/PRELEVEMENT CARTE ZERO FSSI043def106",
                "id": 627
              },
              {
                "date": "2022-09-11T05:00:00.000Z",
                "rdate": "2022-09-11T05:00:00.000Z",
                "currency": "EUR",
                "value": 880,
                "original_wording": "VIREMENT RECU DE M. POTTER",
                "id": 119
              },
              {
                "date": "2022-09-12T05:00:00.000Z",
                "rdate": "2022-09-12T05:00:00.000Z",
                "currency": "EUR",
                "value": -20,
                "original_wording": "F FRAIS PRLV IMP 543,45EUR 20 PROVISION INSUFFISANTE",
                "id": 556
              },
              {
                "date": "2022-09-12T05:00:00.000Z",
                "rdate": "2022-09-12T05:00:00.000Z",
                "currency": "EUR",
                "value": -20,
                "original_wording": "F FRAIS PRLV IMP 9,99EUR 20 PROVISION INSUFFISANTE",
                "id": 750
              },
              {
                "date": "2022-09-12T05:00:00.000Z",
                "rdate": "2022-09-12T05:00:00.000Z",
                "currency": "EUR",
                "value": -89.89,
                "original_wording": "F INT/FRAIS TX DEBIT 15,81%/AN",
                "id": 585
              },
              {
                "date": "2022-09-12T05:00:00.000Z",
                "rdate": "2022-09-12T05:00:00.000Z",
                "currency": "EUR",
                "value": -75.2,
                "original_wording": "PRELEVEMENT DE NAVIGO ANNUEL - G COMUTITRES REF : 3/262663-1/92921 Navigo Annuel",
                "id": 450
              },
              {
                "date": "2022-09-12T05:00:00.000Z",
                "rdate": "2022-09-12T05:00:00.000Z",
                "currency": "EUR",
                "value": -399.89,
                "original_wording": "PRLV SEPA CREDIPAR Motif : 101M3323222 32 VOTRE IDEN",
                "id": 834
              },
              {
                "date": "2022-09-12T05:00:00.000Z",
                "rdate": "2022-09-12T05:00:00.000Z",
                "currency": "EUR",
                "value": -879.78,
                "original_wording": "VIREMENT EMIS AG HOMALONE LOYER",
                "id": 892
              },
              {
                "date": "2022-09-15T05:00:00.000Z",
                "rdate": "2022-09-15T05:00:00.000Z",
                "currency": "EUR",
                "value": -4.99,
                "original_wording": "Cotisation Compte A Composer (rem = 20%)",
                "id": 23
              },
              {
                "date": "2022-09-15T05:00:00.000Z",
                "rdate": "2022-09-15T05:00:00.000Z",
                "currency": "EUR",
                "value": -13.79,
                "original_wording": "PAIEMENT CB PARIS CARREFOUR PARIS CARTE 122131",
                "id": 485
              },
              {
                "date": "2022-09-15T05:00:00.000Z",
                "rdate": "2022-09-15T05:00:00.000Z",
                "currency": "EUR",
                "value": -343.45,
                "original_wording": "PRLV SEPA CREDIPAR 10600220302032 32 VOTRE IDE FR0004123032023",
                "id": 670
              },
              {
                "date": "2022-09-19T05:00:00.000Z",
                "rdate": "2022-09-19T05:00:00.000Z",
                "currency": "EUR",
                "value": -126.99,
                "original_wording": "CARTE X2518 3-4X CB ONEY. COMMERCE ELECTRONIQUE",
                "id": 611
              },
              {
                "date": "2022-09-19T05:00:00.000Z",
                "rdate": "2022-09-19T05:00:00.000Z",
                "currency": "EUR",
                "value": -20,
                "original_wording": "PRELEVEMENT DE LUKO COVER SAS REF : 2RQ0IPC LUKO COVER SAS",
                "id": 511
              },
              {
                "date": "2022-09-28T05:00:00.000Z",
                "rdate": "2022-09-28T05:00:00.000Z",
                "currency": "EUR",
                "value": -15.99,
                "original_wording": "PRELEVEMENT DE BOUYGUES TELECOM YGUES TELECOM REF : PAGP0102EAAE 06xxxxx687",
                "id": 448
              },
              {
                "date": "2022-09-29T05:00:00.000Z",
                "rdate": "2022-09-29T05:00:00.000Z",
                "currency": "EUR",
                "value": -9.99,
                "original_wording": "CARTE X2518 SPOTIFY FRANCE COMMERCE ELECTRONIQUE",
                "id": 350
              },
              {
                "date": "2022-10-02T05:00:00.000Z",
                "rdate": "2022-10-02T05:00:00.000Z",
                "currency": "EUR",
                "value": -3.72,
                "original_wording": "CARTE X2518 APPLE.COM/BILL 3,79 EUR IRLANDE COMMERCE ELECTRONIQUE",
                "id": 813
              },
              {
                "date": "2022-10-03T05:00:00.000Z",
                "rdate": "2022-10-03T05:00:00.000Z",
                "currency": "EUR",
                "value": -19.99,
                "original_wording": "CARTE X2518 PIZZA",
                "id": 256
              },
              {
                "date": "2022-10-06T05:00:00.000Z",
                "rdate": "2022-10-06T05:00:00.000Z",
                "currency": "EUR",
                "value": 2581.45,
                "original_wording": "VIR SEPA RECU /DE FNAC DARTY PARTICIPATIONS ET SERVICES /MOTIF SALAIRE /REF 106837-1",
                "id": 609
              },
              {
                "date": "2022-10-06T05:00:00.000Z",
                "rdate": "2022-10-06T05:00:00.000Z",
                "currency": "EUR",
                "value": -112.32,
                "original_wording": "PRELEVEMENT DE EDF CLIENTS PARTI iers REF : Z012201022 00203 1 S 116",
                "id": 587
              },
              {
                "date": "2022-10-07T05:00:00.000Z",
                "rdate": "2022-10-07T05:00:00.000Z",
                "currency": "EUR",
                "value": -62.9,
                "original_wording": "PAIEMENT CB PARIS CARREFOUR PARIS CARTE 122131",
                "id": 256
              },
              {
                "date": "2022-10-07T05:00:00.000Z",
                "rdate": "2022-10-07T05:00:00.000Z",
                "currency": "EUR",
                "value": -550,
                "original_wording": "VIREMENT EMIS M POTTER",
                "id": 668
              }
            ],
            "balance": 1361.77,
            "last_update": "2022-10-07T05:00:00.000Z",
            "currency": {
              "id": "EUR"
            },
            "type": "checking",
            "usage": "PRIV",
            "id": 123
          }
        ]
      }
    ]
  }

# %%
customer_id = '634021baf832104b5e19e8fb'
url = f"https://api.algoan.com/v2/customers/{customer_id}/analyses"

response = requests.request("post", url, json=payload, headers=headers)

response.json()
# Out:
# {'source': 'CLIENT',
#  'dataOrigin': 'UNKNOWN',
#  'format': 'BUDGET_INSIGHT_V2_0',
#  'status': 'CREATED',
#  'createdAt': '2022-10-13T10:20:14.966Z',
#  'updatedAt': '2022-10-13T10:20:14.966Z',
#  'id': '6347e65eb173b96a78846ba8'}

# %%
analysisid=response.json()['id']
analysisid
# Out:
# '6347e65eb173b96a78846ba8'

# %%
url = f"https://api.algoan.com/v2/customers/{customer_id}/analyses/{analysisid}"

response = requests.request("GET", url, headers=headers)

response.json()
# Out:
# {'source': 'CLIENT',
#  'dataOrigin': 'UNKNOWN',
#  'format': 'BUDGET_INSIGHT_V2_0',
#  'status': 'COMPLETED',
#  'createdAt': '2022-10-13T10:20:14.966Z',
#  'updatedAt': '2022-10-13T10:20:15.107Z',
#  'metadata': {'analysisId': '6347e65eb173b96a78846ba8',
#   'paymentScore': {'minWindowDate': '2022-07-08',
#    'maxWindowDate': '2022-10-07',
#    'numberOfDaysInWindow': 91,
#    'calendar': [{'month': '2022-07', 'nbDays': 24},
#     {'month': '2022-08', 'nbDays': 31},
#     {'month': '2022-09', 'nbDays': 30},
#     {'month': '2022-10', 'nbDays': 7}],
#    'firstTransactionDate': '2022-07-11',
#    'historicalDepth': 89,
#    'lastTransactionGap': 6,
#    'monthlyTransactionCount': 23,
#    'totalTransactionCount': 66},
#   'referenceDate': '2022-10-13',
#   'createdAt': '2022-10-13T10:20:15.102Z',
#   'updatedAt': '2022-10-13T10:20:15.231Z',
#   'numberOfCheckings': 1,
#   'numberOfCreditCard': 0,
#   'numberOfLoans': 0,
#   'numberOfSavings': 0},
# ...

# %%
url = f"https://api.algoan.com/v2/customers/{customer_id}/analyses/{analysisid}/scores"


response = requests.request("GET", url, headers=headers)

response.json()
# Out:
# {'analysisId': '6347e65eb173b96a78846ba8',
#  'paymentScore': {'version': '1.1.0', 'value': 4},
#  'createdAt': '2022-10-13T10:20:15.297Z',
#  'updatedAt': '2022-10-13T10:20:15.297Z'}
